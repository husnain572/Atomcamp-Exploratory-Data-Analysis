# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("HR_Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %% [markdown]
# ### Exploring Attributes

# %%
with pd.option_context('display.max_rows',None,'display.max_columns',None): # to view whole dataset i-e all rows and columns
    display(df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome    Education EducationField  EmployeeCount  \
# 1465                23     Bachelor        Medical              1
# 1466                 6  High School        Medical              1
# 1467                 4       Master  Life Sciences              1
# 1468                 2       Master        Medical              1
# 1469                 8       Master        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe() # we can pass include and exclude argument as well
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000         1470.0
# mean     36.923810   802.485714          9.192517            1.0
# std       9.135373   403.509100          8.106864            0.0
# min      18.000000   102.000000          1.000000            1.0
# 25%      30.000000   465.000000          2.000000            1.0
# 50%      36.000000   802.000000          7.000000            1.0
# 75%      43.000000  1157.000000         14.000000            1.0
# max      60.000000  1499.000000         29.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %% [markdown]
# ## Difference Between `loc` and `iloc`
#
# ### `iloc`
# - Stands for **integer-location based indexing**.
# - It is used for selecting rows and columns **by their numerical positions** (integer indices).
# - **Example**:
#   ```python
#   df.iloc[1:4, 0:2]
#
# ### `loc`
#
# - Stands for **label-location based indexing**.
# - It is used for selecting rows and columns **by their labels** (e.g., column names or row labels).
# - **Example**:
#   ```python
#   df.loc[1:3, ['A', 'B']]

# %%
df.loc[1:50:3,['RelationshipSatisfaction', 'JobRole', 'StockOptionLevel']]
# start, stop,stepper
# Out:
#     RelationshipSatisfaction                    JobRole  StockOptionLevel
# 1                          4         Research Scientist                 1
# 4                          4      Laboratory Technician                 1
# 7                          2      Laboratory Technician                 1
# 10                         3      Laboratory Technician                 1
# 13                         3      Laboratory Technician                 1
# 16                         4         Research Scientist                 2
# 19                         3         Research Scientist                 0
# 22                         3          Research Director                 0
# 25                         4                    Manager                 1
# 28                         4  Healthcare Representative                 1
# 31                         4  Healthcare Representative                 0
# 34                         1         Research Scientist                 1
# ...

# %%
df.iloc[1:4,0:10]
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  EmployeeNumber
# 1                 8  High School  Life Sciences              1               2
# 2                 2     Bachelor          Other              1               4
# 3                 3          PhD  Life Sciences              1               5

# %% [markdown]
# ### Creating a separate, small dataset

# %%
df_new = df.loc[:100, ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department']]
df_new
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department
# 0     41       Yes      Travel_Rarely       1102                   Sales
# 1     49        No  Travel_Frequently        279  Research & Development
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 3     33        No  Travel_Frequently       1392  Research & Development
# 4     27        No      Travel_Rarely        591  Research & Development
# ..   ...       ...                ...        ...                     ...
# 96    24        No      Travel_Rarely       1353                   Sales
# 97    28        No         Non-Travel        120                   Sales
# 98    58        No      Travel_Rarely        682                   Sales
# 99    44        No         Non-Travel        489  Research & Development
# 100   37       Yes      Travel_Rarely        807         Human Resources
#
# [101 rows x 5 columns]

# %%
#will automatically create a column if it doesn't exist and add it at the end

df_new["new_col"] = df.loc[:100, 'JobRole']

df_new
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     41       Yes      Travel_Rarely       1102                   Sales
# 1     49        No  Travel_Frequently        279  Research & Development
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 3     33        No  Travel_Frequently       1392  Research & Development
# 4     27        No      Travel_Rarely        591  Research & Development
# ..   ...       ...                ...        ...                     ...
# 96    24        No      Travel_Rarely       1353                   Sales
# 97    28        No         Non-Travel        120                   Sales
# 98    58        No      Travel_Rarely        682                   Sales
# 99    44        No         Non-Travel        489  Research & Development
# 100   37       Yes      Travel_Rarely        807         Human Resources
#
#                    new_col
# 0          Sales Executive
# 1       Research Scientist
# ...

# %%
#adding a column at a specific location

df_new.insert(loc= 1, column = "new_col2", value = df["Department"])

df_new
# Out:
#      Age                new_col2 Attrition     BusinessTravel  DailyRate  \
# 0     41                   Sales       Yes      Travel_Rarely       1102
# 1     49  Research & Development        No  Travel_Frequently        279
# 2     37  Research & Development       Yes      Travel_Rarely       1373
# 3     33  Research & Development        No  Travel_Frequently       1392
# 4     27  Research & Development        No      Travel_Rarely        591
# ..   ...                     ...       ...                ...        ...
# 96    24                   Sales        No      Travel_Rarely       1353
# 97    28                   Sales        No         Non-Travel        120
# 98    58                   Sales        No      Travel_Rarely        682
# 99    44  Research & Development        No         Non-Travel        489
# 100   37         Human Resources       Yes      Travel_Rarely        807
#
#                  Department                new_col
# ...

# %%
#to drop columns, you need to set axis = 1. by default it is set to 0, meaning rows

df_new=df_new.drop('new_col',axis=1)
df_new
# Out:
#      Age                new_col2 Attrition     BusinessTravel  DailyRate  \
# 0     41                   Sales       Yes      Travel_Rarely       1102
# 1     49  Research & Development        No  Travel_Frequently        279
# 2     37  Research & Development       Yes      Travel_Rarely       1373
# 3     33  Research & Development        No  Travel_Frequently       1392
# 4     27  Research & Development        No      Travel_Rarely        591
# ..   ...                     ...       ...                ...        ...
# 96    24                   Sales        No      Travel_Rarely       1353
# 97    28                   Sales        No         Non-Travel        120
# 98    58                   Sales        No      Travel_Rarely        682
# 99    44  Research & Development        No         Non-Travel        489
# 100   37         Human Resources       Yes      Travel_Rarely        807
#
#                  Department
# 0                     Sales
# 1    Research & Development
# ...

# %%
df_new.drop('new_col2',axis=1,inplace=True)
df_new
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department
# 0     41       Yes      Travel_Rarely       1102                   Sales
# 1     49        No  Travel_Frequently        279  Research & Development
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 3     33        No  Travel_Frequently       1392  Research & Development
# 4     27        No      Travel_Rarely        591  Research & Development
# ..   ...       ...                ...        ...                     ...
# 96    24        No      Travel_Rarely       1353                   Sales
# 97    28        No         Non-Travel        120                   Sales
# 98    58        No      Travel_Rarely        682                   Sales
# 99    44        No         Non-Travel        489  Research & Development
# 100   37       Yes      Travel_Rarely        807         Human Resources
#
# [101 rows x 5 columns]

# %% [markdown]
# ### Changing or inserting a row

# %%
new_row=pd.Series(df_new.shape[1]*[np.nan])
df_new.loc[4]=new_row
df_new
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0    41.0       Yes      Travel_Rarely     1102.0                   Sales
# 1    49.0        No  Travel_Frequently      279.0  Research & Development
# 2    37.0       Yes      Travel_Rarely     1373.0  Research & Development
# 3    33.0        No  Travel_Frequently     1392.0  Research & Development
# 4     NaN       NaN                NaN        NaN                     NaN
# ..    ...       ...                ...        ...                     ...
# 96   24.0        No      Travel_Rarely     1353.0                   Sales
# 97   28.0        No         Non-Travel      120.0                   Sales
# 98   58.0        No      Travel_Rarely      682.0                   Sales
# 99   44.0        No         Non-Travel      489.0  Research & Development
# 100  37.0       Yes      Travel_Rarely      807.0         Human Resources
#
# [101 rows x 5 columns]

# %% [markdown]
# ### Dropping a row

# %%
df_new.drop(0,inplace=True)
df_new
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 1    49.0        No  Travel_Frequently      279.0  Research & Development
# 2    37.0       Yes      Travel_Rarely     1373.0  Research & Development
# 3    33.0        No  Travel_Frequently     1392.0  Research & Development
# 4     NaN       NaN                NaN        NaN                     NaN
# 5    32.0        No  Travel_Frequently     1005.0  Research & Development
# ..    ...       ...                ...        ...                     ...
# 96   24.0        No      Travel_Rarely     1353.0                   Sales
# 97   28.0        No         Non-Travel      120.0                   Sales
# 98   58.0        No      Travel_Rarely      682.0                   Sales
# 99   44.0        No         Non-Travel      489.0  Research & Development
# 100  37.0       Yes      Travel_Rarely      807.0         Human Resources
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Dealing with Nulls

# %%
df_new.isnull()
# Out:
#        Age  Attrition  BusinessTravel  DailyRate  Department
# 1    False      False           False      False       False
# 2    False      False           False      False       False
# 3    False      False           False      False       False
# 4     True       True            True       True        True
# 5    False      False           False      False       False
# ..     ...        ...             ...        ...         ...
# 96   False      False           False      False       False
# 97   False      False           False      False       False
# 98   False      False           False      False       False
# 99   False      False           False      False       False
# 100  False      False           False      False       False
#
# [100 rows x 5 columns]

# %%
df_new.isnull().sum()
# Out:
# Age               1
# Attrition         1
# BusinessTravel    1
# DailyRate         1
# Department        1
# dtype: int64

# %%
df_new.isnull().sum().sum()
# Out:
# 5

# %%
df['Attrition'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1470, dtype: bool

# %%
df_new['Attrition'].isnull().sum()
# Out:
# 1

# %%
# fill missing values
df_new.fillna(0, inplace=True) # all the missing values of dataset are filled by zero

# %% [markdown]
# ### Drop duplicates

# %%
df_new['Age'].duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 96      True
# 97      True
# 98     False
# 99      True
# 100     True
# Name: Age, Length: 100, dtype: bool

# %%
df_new['Attrition'].drop_duplicates(inplace=True)

# %%
df_new.drop_duplicates(inplace=True)

# %%
df_new.isnull().sum()
# Out:
# Age               0
# Attrition         0
# BusinessTravel    0
# DailyRate         0
# Department        0
# dtype: int64

# %% [markdown]
# ### Grouping and aggregate functions

# %%
df.groupby("Department").count()
# Out:
#                         Age  Attrition  BusinessTravel  DailyRate  \
# Department
# Human Resources          63         63              63         63
# Research & Development  961        961             961        961
# Sales                   446        446             446        446
#
#                         DistanceFromHome  Education  EducationField  \
# Department
# Human Resources                       63         63              63
# Research & Development               961        961             961
# Sales                                446        446             446
#
#                         EmployeeCount  EmployeeNumber  \
# Department
# Human Resources                    63              63
# Research & Development            961             961
# Sales                             446             446
#
#                         EnvironmentSatisfaction  ...  \
# Department                                       ...
# Human Resources                              63  ...
# ...

# %%
#grouping on multiple columns

# df_new.groupby(["DailyRate", "Age"]).mean()
df.groupby("Department")[["Age", "DailyRate"]].mean()
# Out:
#                               Age   DailyRate
# Department
# Human Resources         37.809524  751.539683
# Research & Development  37.042664  806.851197
# Sales                   36.542601  800.275785

# %%
#replacing value at index 1 in the Age column with null

df_new.loc[1, "Age"] = np.nan
df_new
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 1     NaN        No  Travel_Frequently      279.0  Research & Development
# 2    37.0       Yes      Travel_Rarely     1373.0  Research & Development
# 3    33.0        No  Travel_Frequently     1392.0  Research & Development
# 4     0.0         0                  0        0.0                       0
# 5    32.0        No  Travel_Frequently     1005.0  Research & Development
# ..    ...       ...                ...        ...                     ...
# 96   24.0        No      Travel_Rarely     1353.0                   Sales
# 97   28.0        No         Non-Travel      120.0                   Sales
# 98   58.0        No      Travel_Rarely      682.0                   Sales
# 99   44.0        No         Non-Travel      489.0  Research & Development
# 100  37.0       Yes      Travel_Rarely      807.0         Human Resources
#
# [100 rows x 5 columns]

# %%
df_new.groupby("BusinessTravel").count()
# Out:
#                    Age  Attrition  DailyRate  Department
# BusinessTravel
# 0                    1          1          1           1
# Non-Travel           7          7          7           7
# Travel_Frequently   16         17         17          17
# Travel_Rarely       75         75         75          75

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome    Education EducationField  EmployeeCount  \
# ...

# %%
df['BusinessTravel'].str.upper()
# Out:
# 0           TRAVEL_RARELY
# 1       TRAVEL_FREQUENTLY
# 2           TRAVEL_RARELY
# 3       TRAVEL_FREQUENTLY
# 4           TRAVEL_RARELY
#               ...
# 1465    TRAVEL_FREQUENTLY
# 1466        TRAVEL_RARELY
# 1467        TRAVEL_RARELY
# 1468    TRAVEL_FREQUENTLY
# 1469        TRAVEL_RARELY
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
df['BusinessTravel'].apply(str.upper)
# Out:
# 0           TRAVEL_RARELY
# 1       TRAVEL_FREQUENTLY
# 2           TRAVEL_RARELY
# 3       TRAVEL_FREQUENTLY
# 4           TRAVEL_RARELY
#               ...
# 1465    TRAVEL_FREQUENTLY
# 1466        TRAVEL_RARELY
# 1467        TRAVEL_RARELY
# 1468    TRAVEL_FREQUENTLY
# 1469        TRAVEL_RARELY
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
# applying lambda function
df['BusinessTravel'].apply(lambda x:x[0])
# Out:
# 0       r
# 1       r
# 2       r
# 3       r
# 4       r
#        ..
# 1465    r
# 1466    r
# 1467    r
# 1468    r
# 1469    r
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
df['BusinessTravel'].apply(lambda x:x[0])+df['Department'].apply(lambda x:x[1])
# Out:
# 0       Ta
# 1       Te
# 2       Te
# 3       Te
# 4       Te
#         ..
# 1465    Te
# 1466    Te
# 1467    Te
# 1468    Ta
# 1469    Te
# Length: 1470, dtype: object

# %%
df.groupby('Department')[["StandardHours","DistanceFromHome"]].agg(np.mean)
df.groupby('Department')[["Age", "DistanceFromHome"]].agg(np.mean)
# Out:
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/3766584066.py:1: FutureWarning: The provided callable <function mean at 0x1130d1e40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('Department')[["StandardHours","DistanceFromHome"]].agg(np.mean)
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/3766584066.py:2: FutureWarning: The provided callable <function mean at 0x1130d1e40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('Department')[["Age", "DistanceFromHome"]].agg(np.mean)
#                               Age  DistanceFromHome
# Department
# Human Resources         37.809524          8.698413
# Research & Development  37.042664          9.144641
# ...

# %%
df.groupby('Department')[['Age','DailyRate']].agg('count')
# Out:
#                         Age  DailyRate
# Department
# Human Resources          63         63
# Research & Development  961        961
# Sales                   446        446

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.groupby("JobRole").agg({'Age':[np.mean,np.max],'HourlyRate':[np.max,'count']})
# Out:
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/3709554212.py:1: FutureWarning: The provided callable <function mean at 0x1130d1e40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("JobRole").agg({'Age':[np.mean,np.max],'HourlyRate':[np.max,'count']})
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/3709554212.py:1: FutureWarning: The provided callable <function max at 0x1130d1440> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby("JobRole").agg({'Age':[np.mean,np.max],'HourlyRate':[np.max,'count']})
#                                  Age     HourlyRate
#                                 mean max        max count
# JobRole
# Healthcare Representative  39.809160  60        100   131
# ...

# %%
df.groupby(['Education','Age']).agg({"JobRole":['count'],'JobSatisfaction':[np.mean,np.max]})
# Out:
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/2938222424.py:1: FutureWarning: The provided callable <function mean at 0x1130d1e40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(['Education','Age']).agg({"JobRole":['count'],'JobSatisfaction':[np.mean,np.max]})
# /var/folders/qz/0x263kfx5dq176fbjd08nvqc0000gn/T/ipykernel_4647/2938222424.py:1: FutureWarning: The provided callable <function max at 0x1130d1440> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['Education','Age']).agg({"JobRole":['count'],'JobSatisfaction':[np.mean,np.max]})
#               JobRole JobSatisfaction
#                 count            mean max
# Education Age
# Bachelor  18        2        4.000000   4
# ...

# %% [markdown]
# Filtering

# %%
df[df["Age"] > 30]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1463   31        No         Non-Travel        325  Research & Development
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome    Education EducationField  EmployeeCount  \
# ...

# %%
#use bitwise operators for and or i.e. & and |

df[(df["Age"] > 30) & (df["DailyRate"] > 1000)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1455   40        No      Travel_Rarely       1322  Research & Development
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1457   40        No      Travel_Rarely       1194  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
#
#       DistanceFromHome Education EducationField  EmployeeCount  \
# ...

# %%
df[(df["Age"] > 30) | (df["DailyRate"] > 1000)]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome    Education EducationField  EmployeeCount  \
# ...

# %%
df[df["Attrition"] == "Yes"]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome    Education    EducationField  EmployeeCount  \
# ...

# %%
#changing bool series to another datatype 

(df["Attrition"] == "Yes").astype(int)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64
