# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("HR_Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
#using the mean() method directly on the group by object and passing it kwargs (keyword arguments)
df.groupby('BusinessTravel').mean(numeric_only=True)
# Out:
#                          Age   DailyRate  DistanceFromHome  EmployeeCount  \
# BusinessTravel
# Non-Travel         36.620000  816.960000          9.760000            1.0
# Travel_Frequently  36.454874  792.628159          9.277978            1.0
# Travel_Rarely      37.092042  803.022052          9.088207            1.0
#
#                    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# BusinessTravel
# Non-Travel            1064.626667                 2.733333   64.866667
# Travel_Frequently     1014.898917                 2.693141   65.097473
# Travel_Rarely         1021.793864                 2.727709   66.249281
#
#                    JobInvolvement  JobLevel  JobSatisfaction  ...  \
# BusinessTravel                                                ...
# Non-Travel               2.633333  2.040000         2.793333  ...
# Travel_Frequently        2.736462  2.014440         2.790614  ...
# Travel_Rarely            2.742090  2.080537         2.702780  ...
#
# ...

# %%
df.groupby("BusinessTravel").agg('max',numeric_only=True,min_count=100)
# Out:
#                    Age  DailyRate  DistanceFromHome  EmployeeCount  \
# BusinessTravel
# Non-Travel          59       1496                29              1
# Travel_Frequently   60       1499                29              1
# Travel_Rarely       60       1498                29              1
#
#                    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# BusinessTravel
# Non-Travel                   2057                        4         100
# Travel_Frequently            2065                        4         100
# Travel_Rarely                2068                        4         100
#
#                    JobInvolvement  JobLevel  JobSatisfaction  ...  \
# BusinessTravel                                                ...
# Non-Travel                      4         5                4  ...
# Travel_Frequently               4         5                4  ...
# Travel_Rarely                   4         5                4  ...
#
# ...

# %% [markdown]
# ### Making Functions

# %%
df['BusinessTravel'].nunique()
# Out:
# 3

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
#a function to print out information about the unique values in each column of dataframe
def print_unique_values(data_frame):
    for column in data_frame:
        print("Column name:",column)
        print("Total uniques values:",data_frame[column].nunique())
        print("Unique values:",data_frame[column].unique())
        print("----------------------------------------------------")

# %%
print_unique_values(df)
# Out:
# Column name: Age
# Total uniques values: 43
# Unique values: [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ----------------------------------------------------
# Column name: Attrition
# Total uniques values: 2
# Unique values: ['Yes' 'No']
# ----------------------------------------------------
# Column name: BusinessTravel
# Total uniques values: 3
# Unique values: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ----------------------------------------------------
# Column name: DailyRate
# Total uniques values: 886
# Unique values: [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
# ...

# %% [markdown]
# ### String Manipulation and Regular Expressions (RegEx)

# %%
df['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
df['BusinessTravel'].str.split("_").str.join(" ")
# Out:
# 0           Travel Rarely
# 1       Travel Frequently
# 2           Travel Rarely
# 3       Travel Frequently
# 4           Travel Rarely
#               ...
# 1465    Travel Frequently
# 1466        Travel Rarely
# 1467        Travel Rarely
# 1468    Travel Frequently
# 1469        Travel Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
df['BusinessTravel'].str.replace("_"," ")
# Out:
# 0           Travel Rarely
# 1       Travel Frequently
# 2           Travel Rarely
# 3       Travel Frequently
# 4           Travel Rarely
#               ...
# 1465    Travel Frequently
# 1466        Travel Rarely
# 1467        Travel Rarely
# 1468    Travel Frequently
# 1469        Travel Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"[_-]" #this regex looks for underscore and hyphen INDIVIDUALLY

df['BusinessTravel']=df["BusinessTravel"].str.replace(reg, " ",regex=True)
df['BusinessTravel']
# Out:
# 0           Travel Rarely
# 1       Travel Frequently
# 2           Travel Rarely
# 3       Travel Frequently
# 4           Travel Rarely
#               ...
# 1465    Travel Frequently
# 1466        Travel Rarely
# 1467        Travel Rarely
# 1468    Travel Frequently
# 1469        Travel Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
# !pip install regex

# %%
# pip install --upgrade pip

# %%
#creating a column with unwanted characters. I am replacing hyphens and underscores with junk: _*^7s )87
import regex as re
reg = r"[_-]"
replacement=re.escape("_*^7s )87")
sample_column = df["BusinessTravel"].str.replace(reg,replacement)
sample_column
# Out:
# 0           Travel Rarely
# 1       Travel Frequently
# 2           Travel Rarely
# 3       Travel Frequently
# 4           Travel Rarely
#               ...
# 1465    Travel Frequently
# 1466        Travel Rarely
# 1467        Travel Rarely
# 1468    Travel Frequently
# 1469        Travel Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
# Use re.escape to escape special characters in your replacement string
replacement = re.escape('_*^7s )87')  # Escaping special characters in the replacement string

sample_col = df['BusinessTravel'].str.replace(" ", replacement)
sample_col
# Out:
# 0           Travel_\*\^7s\ \)87Rarely
# 1       Travel_\*\^7s\ \)87Frequently
# 2           Travel_\*\^7s\ \)87Rarely
# 3       Travel_\*\^7s\ \)87Frequently
# 4           Travel_\*\^7s\ \)87Rarely
#                     ...
# 1465    Travel_\*\^7s\ \)87Frequently
# 1466        Travel_\*\^7s\ \)87Rarely
# 1467        Travel_\*\^7s\ \)87Rarely
# 1468    Travel_\*\^7s\ \)87Frequently
# 1469        Travel_\*\^7s\ \)87Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"[_-]" #will look for _ and -
sample_col=sample_col.str.replace(reg," ",regex=True)
sample_col
# Out:
# 0           Travel \*\^7s\ \)87Rarely
# 1       Travel \*\^7s\ \)87Frequently
# 2           Travel \*\^7s\ \)87Rarely
# 3       Travel \*\^7s\ \)87Frequently
# 4           Travel \*\^7s\ \)87Rarely
#                     ...
# 1465    Travel \*\^7s\ \)87Frequently
# 1466        Travel \*\^7s\ \)87Rarely
# 1467        Travel \*\^7s\ \)87Rarely
# 1468    Travel \*\^7s\ \)87Frequently
# 1469        Travel \*\^7s\ \)87Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"[A-G]" #will look for letters A to G capital
sample_col=sample_col.str.replace(reg," ",regex=True)
sample_col
# Out:
# 0           Travel \*\^7s\ \)87Rarely
# 1       Travel \*\^7s\ \)87 requently
# 2           Travel \*\^7s\ \)87Rarely
# 3       Travel \*\^7s\ \)87 requently
# 4           Travel \*\^7s\ \)87Rarely
#                     ...
# 1465    Travel \*\^7s\ \)87 requently
# 1466        Travel \*\^7s\ \)87Rarely
# 1467        Travel \*\^7s\ \)87Rarely
# 1468    Travel \*\^7s\ \)87 requently
# 1469        Travel \*\^7s\ \)87Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
#reg = r"[a-z]+" #will look for small a to z and replace consecutive instances ONCE

text = "abc123def456ghi"
result = re.sub(r"[a-z]+", "X", text)
print(result)
# Out:
# X123X456X

# %%
reg = r"[a-z]+" #will look for small a to z and replace consecutive instances ONCE
sample_col=sample_col.str.replace(reg," ",regex=True)
sample_col

sample_col
# Out:
# 0       T  \*\^7 \ \)87R
# 1       T  \*\^7 \ \)87
# 2       T  \*\^7 \ \)87R
# 3       T  \*\^7 \ \)87
# 4       T  \*\^7 \ \)87R
#               ...
# 1465    T  \*\^7 \ \)87
# 1466    T  \*\^7 \ \)87R
# 1467    T  \*\^7 \ \)87R
# 1468    T  \*\^7 \ \)87
# 1469    T  \*\^7 \ \)87R
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"\s" #will look for spaces. \s represents space. s alone will look for the letter s. 
sample_col=sample_col.str.replace(reg," ",regex=True)
sample_col
# Out:
# 0       T  \*\^7 \ \)87R
# 1       T  \*\^7 \ \)87
# 2       T  \*\^7 \ \)87R
# 3       T  \*\^7 \ \)87
# 4       T  \*\^7 \ \)87R
#               ...
# 1465    T  \*\^7 \ \)87
# 1466    T  \*\^7 \ \)87R
# 1467    T  \*\^7 \ \)87R
# 1468    T  \*\^7 \ \)87
# 1469    T  \*\^7 \ \)87R
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"[a-z0-9A-Z\s]" #small and capital letters, numbers and spaces 
sample_col=sample_col.str.replace(reg,"",regex=True)
sample_col
# Out:
# 0       \*\^\\)
# 1       \*\^\\)
# 2       \*\^\\)
# 3       \*\^\\)
# 4       \*\^\\)
#          ...
# 1465    \*\^\\)
# 1466    \*\^\\)
# 1467    \*\^\\)
# 1468    \*\^\\)
# 1469    \*\^\\)
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"\w" #all digits and numbers. \W will look for the opposite, i.e. everything BUT digits and numbers
sample_col=sample_col.str.replace(reg,"",regex=True)

sample_col
# Out:
# 0       \*\^\\)
# 1       \*\^\\)
# 2       \*\^\\)
# 3       \*\^\\)
# 4       \*\^\\)
#          ...
# 1465    \*\^\\)
# 1466    \*\^\\)
# 1467    \*\^\\)
# 1468    \*\^\\)
# 1469    \*\^\\)
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
reg = r"^[A-Za-z]" #will look for all capital and small letters
reg = r"^[A-Za-z]+" #will look for all capital and small letters BUT will replace all consecutive instances of these characters with ONE replacement (because of + at the end)
reg = r"[0-9]" #will look for all digits
reg = r"[0-9A-Za-z]" #will look for all capital and small letters and digits
reg = r"^[0-9A-Za-z]" #will look for all capital and small letters and digits but at the START of the input string (^ at the start OUTSIDE sq brackets)
reg = r"[0-9]$" #will look for digits but at the END of the input string ($ at the END outside the sq brackets)
reg = r"[^A-Za-z]" #will look for everything EXCEPT capital and small letters
reg = r"[^A-Za-z]+" #will look for everything EXCEPT capital and small letters (because of ^) AND will replace all consecutive instances of these characters with ONE replacement (because of + at the end)
reg = r"[rav]" #will look for r, a and v INDIVIDUALLY
reg = r"(rav)" #will treat rav as a group and look for this exact pattern "rav"



sample_col.str.replace(reg, "")
# Out:
# 0       \*\^\\)
# 1       \*\^\\)
# 2       \*\^\\)
# 3       \*\^\\)
# 4       \*\^\\)
#          ...
# 1465    \*\^\\)
# 1466    \*\^\\)
# 1467    \*\^\\)
# 1468    \*\^\\)
# 1469    \*\^\\)
# Name: BusinessTravel, Length: 1470, dtype: object

# %% [markdown]
# ### PLOTTING WITH A DATAFRAME
# #### Two bar plots on the same figure for education column. One represents attrition == yes and the other attrition == no

# %%
a=df.loc[df['Attrition']=='Yes',"Education"].value_counts()
b=df.loc[df['Attrition']=='No','Education'].value_counts()

# %%
a
# Out:
# Education
# Master         99
# PhD            58
# Bachelor       44
# High School    31
# Post-Doc        5
# Name: count, dtype: int64

# %%
b
# Out:
# Education
# Master         473
# PhD            340
# Bachelor       238
# High School    139
# Post-Doc        43
# Name: count, dtype: int64

# %%
plt.bar(a.index,a.values,color='r',label='Attrition yes')
plt.bar(b.index,b.values,color='g', alpha = 0.3,label='Attrition No')
plt.legend()

# %% [markdown]
# ### PD.CUT
#
# This is a way to change numerical, continuous data to categorical data

# %%
df2=pd.DataFrame(df['Age'].copy(),columns=['Age'])
df2
# Out:
#       Age
# 0      41
# 1      49
# 2      37
# 3      33
# 4      27
# ...   ...
# 1465   36
# 1466   39
# 1467   27
# 1468   49
# 1469   34
#
# [1470 rows x 1 columns]

# %%
pd.cut(df2['Age'],bins=5)
# Out:
# 0       (34.8, 43.2]
# 1       (43.2, 51.6]
# 2       (34.8, 43.2]
# 3       (26.4, 34.8]
# 4       (26.4, 34.8]
#             ...
# 1465    (34.8, 43.2]
# 1466    (34.8, 43.2]
# 1467    (26.4, 34.8]
# 1468    (43.2, 51.6]
# 1469    (26.4, 34.8]
# Name: Age, Length: 1470, dtype: category
# Categories (5, interval[float64, right]): [(17.958, 26.4] < (26.4, 34.8] < (34.8, 43.2] < (43.2, 51.6] < (51.6, 60.0]]

# %%
labels=['teen','young adult','adult','senior']
bins=[13,24,30,60,100]
df2['Age Category']=pd.cut(df2['Age'],bins=bins,labels=labels,right=False)
df2

#adding a new column Age Category to df2 using pd.cut
#the kwarg right = True/False tells us if we want the right (upper) bound to be included. 
#if right = True, then for example 13-20 will be teens INCLUSIVE (i.e. age 20 will also come under teen)
#if right = False, then upper bound isn't included so teen would be less than 20, NOT inclusive of 20
#this applies to all the bins
# Out:
#       Age Age Category
# 0      41        adult
# 1      49        adult
# 2      37        adult
# 3      33        adult
# 4      27  young adult
# ...   ...          ...
# 1465   36        adult
# 1466   39        adult
# 1467   27  young adult
# 1468   49        adult
# 1469   34        adult
#
# [1470 rows x 2 columns]

# %%
df2.loc[df2["Age"] == 20, :]
# Out:
#       Age Age Category
# 102    20         teen
# 487    20         teen
# 513    20         teen
# 662    20         teen
# 689    20         teen
# 731    20         teen
# 776    20         teen
# 856    20         teen
# 876    20         teen
# 1178   20         teen
# 1197   20         teen

# %% [markdown]
# ### HEATMAP AND CORRELATION

# %%
correlation = df.select_dtypes(include=['number']).corr()
correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  \
# Age                       1.000000   0.010661         -0.001686
# DailyRate                 0.010661   1.000000         -0.004985
# DistanceFromHome         -0.001686  -0.004985          1.000000
# EmployeeCount                  NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075
# HourlyRate                0.024287   0.023381          0.031131
# JobInvolvement            0.029820   0.046135          0.008783
# JobLevel                  0.509604   0.002966          0.005303
# JobSatisfaction          -0.004892   0.030571         -0.003669
# MonthlyIncome             0.497855   0.007707         -0.017014
# MonthlyRate               0.028051  -0.032182          0.027473
# NumCompaniesWorked        0.299635   0.038153         -0.029251
# PercentSalaryHike         0.003634   0.022704          0.040235
# ...

# %%
correlation.loc["Age": "EmployeeCount", "Age": "EmployeeCount"]
# Out:
#                        Age  DailyRate  DistanceFromHome  EmployeeCount
# Age               1.000000   0.010661         -0.001686            NaN
# DailyRate         0.010661   1.000000         -0.004985            NaN
# DistanceFromHome -0.001686  -0.004985          1.000000            NaN
# EmployeeCount          NaN        NaN               NaN            NaN

# %%
correlation.iloc[:4,:4]
# Out:
#                        Age  DailyRate  DistanceFromHome  EmployeeCount
# Age               1.000000   0.010661         -0.001686            NaN
# DailyRate         0.010661   1.000000         -0.004985            NaN
# DistanceFromHome -0.001686  -0.004985          1.000000            NaN
# EmployeeCount          NaN        NaN               NaN            NaN

# %%
sns.heatmap(correlation.iloc[:4, :4], cmap = "Spectral") #plotting only first 4 rows and first 4 columns from the correlation matrix
# Out:
# <Axes: >

# %%
sns.heatmap(correlation, cmap = "Spectral")
# Out:
# <Axes: >
